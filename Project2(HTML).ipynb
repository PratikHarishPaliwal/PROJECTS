# %%
import pandas as pd
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import os
os.chdir("E:/DS_HMWRKS/PROJECT2/")

Tr_set = pd.read_csv("training_set.csv")
Ts_set = pd.read_csv("testing_set.csv")

# %%
Tr_set.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1              NaN             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
Ts_set.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
#MISSING DATA TREATMENT
print(Tr_set.isna().sum())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Ts_set.isna().sum())
# Out:
# Loan_ID               0
# Gender               15
# Married               3
# Dependents           15
# Education             1
# Self_Employed        32
# ApplicantIncome       2
# CoapplicantIncome     1
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
# ***************************************
# +++++++++++++++++++++++++++++++++++++++
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
from PM007 import replacer
replacer(Tr_set)
replacer(Ts_set)

# %%
print(Tr_set.isna().sum())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Ts_set.isna().sum())
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# ***************************************
# +++++++++++++++++++++++++++++++++++++++
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
#skew
print(Tr_set.skew())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Ts_set.skew())
# Out:
# ApplicantIncome      6.538870
# CoapplicantIncome    7.492000
# LoanAmount           2.726601
# Loan_Amount_Term    -2.389680
# Credit_History      -1.963600
# dtype: float64
# ***************************************
# +++++++++++++++++++++++++++++++++++++++
# ApplicantIncome      8.441375
# CoapplicantIncome    4.257357
# LoanAmount           2.238688
# Loan_Amount_Term    -2.701307
# Credit_History      -1.794114
# dtype: float64

# %%
print(Tr_set.ApplicantIncome.unique())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Tr_set.CoapplicantIncome.unique())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Tr_set.LoanAmount.unique())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Tr_set.Loan_Amount_Term.unique())
print("***************************************")
print("+++++++++++++++++++++++++++++++++++++++")
print(Tr_set.Credit_History.unique())
# Out:
# [ 5849.          5405.54084967  3000.          2583.
#   6000.          5417.          2333.          3036.
#   4006.         12841.          3200.          2500.
#   3073.          1853.          1299.          3596.
#   3510.          4887.          2600.          7660.
#   5955.          3365.          3717.          9560.
#   2799.          4226.          1442.          3750.
#   4166.          3167.          4692.          3500.
#  12500.          2275.          1828.          3667.
#   3748.          3600.          1800.          2400.
#   3941.          4695.          3410.          5649.
#   5821.          2645.          4000.          1928.
#   3086.          4230.          4616.         11500.
#   2708.          2132.          3366.          8080.
#   3357.          3029.          2609.          4945.
#   5726.         10750.          7100.          4300.
#   3208.          1875.          4755.          5266.
#   1000.          3333.          3846.          2395.
# ...

# %%
#hifh skew in app and coapp :

from numpy import log
q=[]
for i in Tr_set.ApplicantIncome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
Tr_set.ApplicantIncome=q  
Tr_set.ApplicantIncome.skew()
# Out:
# 0.47756159217535543

# %%
from numpy import log
q=[]
for i in Ts_set.ApplicantIncome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
Ts_set.ApplicantIncome=q  
Ts_set.ApplicantIncome.skew()
# Out:
# -5.25720324127368

# %%
from numpy import log
q=[]
for i in Tr_set.CoapplicantIncome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
Tr_set.CoapplicantIncome=q  
Tr_set.CoapplicantIncome.skew()
# Out:
# -0.17292022894757203

# %%
from numpy import log
q=[]
for i in Ts_set.CoapplicantIncome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
Ts_set.CoapplicantIncome=q  
Ts_set.CoapplicantIncome.skew()
# Out:
# -0.24688868882529807

# %%
#DATA SPLIT
cat_Tr = []
con_Tr = []
for i in Tr_set.columns:
        if(Tr_set[i].dtypes == "object"):
            cat_Tr.append(i)
        else:
            con_Tr.append(i)
print("cat_Tr:",cat_Tr,type(cat_Tr),"\n con_Tr:",con_Tr,type(con_Tr))
# Out:
# cat_Tr: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status'] <class 'list'>
#  con_Tr: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History'] <class 'list'>

# %%
Y=Tr_set[["Loan_Status"]]
print(Y)
# Out:
#     Loan_Status
# 0             Y
# 1             N
# 2             Y
# 3             Y
# 4             Y
# ..          ...
# 609           Y
# 610           Y
# 611           Y
# 612           Y
# 613           N
#
# [614 rows x 1 columns]

# %%
for i in cat_Tr:
    print(i,Tr_set[i].unique(),"\n")
print("++++++++++++++++++++++++++++++++++++++++++++++++++")
print ("*************************************************")
for i in con_Tr:
    print (i,Tr_set[i].unique(),"\n")
# Out:
# Loan_ID ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
X = Tr_set.drop(labels=["Loan_ID","Loan_Status"],axis=1)
X.head(4)
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No         8.674026
# 1   Male     Yes          1      Graduate            No         8.595180
# 2   Male     Yes          0      Graduate           Yes         8.006368
# 3   Male     Yes          0  Not Graduate            No         7.856707
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0           0.000000  146.412162             360.0             1.0
# 1           7.318540  128.000000             360.0             1.0
# 2           0.000000   66.000000             360.0             1.0
# 3           7.765569  120.000000             360.0             1.0
#
#   Property_Area
# 0         Urban
# 1         Rural
# 2         Urban
# 3         Urban

# %%
#Preprosessing
from PM007 import ANOVA,chisquare

for i in con_Tr:
    print("--------","Loan_Status vs",i,"-------")
    print(ANOVA(Tr_set,"Loan_Status",i))
# Out:
# -------- Loan_Status vs ApplicantIncome -------
# 0.795
# -------- Loan_Status vs CoapplicantIncome -------
# 0.134
# -------- Loan_Status vs LoanAmount -------
# 0.368
# -------- Loan_Status vs Loan_Amount_Term -------
# 0.604
# -------- Loan_Status vs Credit_History -------
# 0.0

# %%
for i in cat_Tr:
    print("--------","Loan_Status vs",i,"-------")
    print(chisquare(Tr_set,"Loan_Status",i))
# Out:
# -------- Loan_Status vs Loan_ID -------
# 0.4810242844003618
# -------- Loan_Status vs Gender -------
# 0.7391461310869638
# -------- Loan_Status vs Married -------
# 0.029608580862582116
# -------- Loan_Status vs Dependents -------
# 0.3688663081366005
# -------- Loan_Status vs Education -------
# 0.04309962129357355
# -------- Loan_Status vs Self_Employed -------
# 0.9710746411403309
# -------- Loan_Status vs Property_Area -------
# 0.0021360187811644915
# -------- Loan_Status vs Loan_Status -------
# 1.544676456058992e-134

# %%
#OutLyers
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
ss.fit(X[con_Tr])
# Out:
# StandardScaler()

# %%
#Zscores(from{ss.fitX[con_Tr]})
X1 = pd.DataFrame(ss.transform(X[con_Tr]),columns=con_Tr)

# %%
from PM007 import outliers
OL = outliers(X1)

# %%
OL
# Out:
# [14,
#  68,
#  94,
#  130,
#  133,
#  155,
#  171,
#  177,
#  183,
#  185,
#  216,
#  242,
#  262,
#  278,
#  308,
#  313,
#  333,
#  369,
#  409,
#  432,
#  443,
#  468,
#  487,
#  495,
#  497,
#  506,
#  523,
#  525,
#  546,
#  561,
#  575,
#  585,
#  600,
#  604]

# %%
#Removing outlyers and re indexing 
X = X.drop(index=OL,axis=0)
Y = Y.drop(index=OL,axis=0)

# %%
X.index = range(0,X.shape[0])
Y.index = range(0,Y.shape[0])

# %%
from PM007 import preprocessing
Xnew = preprocessing(X)

# %%
Xnew.head(4)
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.694224          -1.127440    0.164382          0.238753
# 1         0.546118           0.772361   -0.154732          0.238753
# 2        -0.559915          -1.127440   -1.229297          0.238753
# 3        -0.841040           0.888404   -0.293386          0.238753
#
#    Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 0        0.455034              0            1           1            0
# 1        0.455034              0            1           0            1
# 2        0.455034              0            1           0            1
# 3        0.455034              0            1           0            1
#
#    Dependents_0  Dependents_1  Dependents_2  Dependents_3+  \
# 0             1             0             0              0
# 1             0             1             0              0
# 2             1             0             0              0
# ...

# %%
#TTS
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)
#DTC since data is not very linear 
#model1(X{not removing columns obtained from ANOVA + Chisquare})
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion="entropy",random_state=21,max_depth=2)
model = dtc.fit(xtrain,ytrain)
pred_tr = model.predict(xtrain)
pred_ts = model.predict(xtest)
from sklearn.metrics import accuracy_score
tr_acc = accuracy_score(ytrain,pred_tr)
ts_acc = accuracy_score(ytest,pred_ts)

# %%
print("tr_acc",tr_acc)

print("ts_acc",ts_acc)

print("Xnew.shape",Xnew.shape)
# Out:
# tr_acc 0.834051724137931
# ts_acc 0.7413793103448276
# Xnew.shape (580, 20)

# %%
tr_acc
# Out:
# 0.834051724137931

# %%
ts_acc
# Out:
# 0.7413793103448276

# %%
#Model2
X = X[["Credit_History","CoapplicantIncome","Property_Area","Education","Married"]]
Xnew = preprocessing(X)
Xnew.head(4)
# Out:
#    Credit_History  CoapplicantIncome  Property_Area_Rural  \
# 0        0.455034          -1.127440                    0
# 1        0.455034           0.772361                    1
# 2        0.455034          -1.127440                    0
# 3        0.455034           0.888404                    0
#
#    Property_Area_Semiurban  Property_Area_Urban  Education_Graduate  \
# 0                        0                    1                   1
# 1                        0                    0                   1
# 2                        0                    1                   1
# 3                        0                    1                   0
#
#    Education_Not Graduate  Married_No  Married_Yes
# 0                       0           1            0
# 1                       0           0            1
# 2                       0           0            1
# 3                       1           0            1

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Y,test_size=0.2,random_state=21)
Xnew.shape
# Out:
# (580, 9)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion="entropy",random_state=21,max_depth=2)
model = dtc.fit(xtrain,ytrain)
pred_tr = model.predict(xtrain)
pred_ts = model.predict(xtest)
from sklearn.metrics import accuracy_score
tr_acc = accuracy_score(ytrain,pred_tr)
ts_acc = accuracy_score(ytest,pred_ts)

# %%
print("tr_acc",tr_acc)

print("ts_acc",ts_acc)
# Out:
# tr_acc 0.834051724137931
# ts_acc 0.7413793103448276

# %%
tr_acc
# Out:
# 0.834051724137931

# %%
ts_acc
# Out:
# 0.7413793103448276

# %%
#Model3( Using Random Forest Too ) 
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion="entropy",random_state=21,max_depth=2)
model = rfc.fit(xtrain,ytrain)
pred_tr_rf = model.predict(xtrain)
pred_ts_rf = model.predict(xtest)
from sklearn.metrics import accuracy_score
tr_acc_rf = accuracy_score(ytrain,pred_tr_rf)
ts_acc_rf = accuracy_score(ytest,pred_ts_rf)

# %%
print("tr_acc",tr_acc_rf)

print("ts_acc",ts_acc_rf)
# Out:
# tr_acc 0.834051724137931
# ts_acc 0.7413793103448276

# %%
tr_acc_rf
# Out:
# 0.834051724137931

# %%
ts_acc_rf
# Out:
# 0.7413793103448276

# %%
#GridsearchCV using Random forest 
tuning_grid = {"max_depth":range(2,5,1),"criterion":["gini","entropy"],"n_estimators":range(20,30,1)}
from sklearn.model_selection import GridSearchCV
rfc = RandomForestClassifier(random_state=21)
cv = GridSearchCV(rfc,tuning_grid,scoring="accuracy",cv=4)

cvmodel = cv.fit(xtrain,ytrain)

# %%
cvmodel.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'n_estimators': 20}

# %%
rfc = RandomForestClassifier(criterion='gini', max_depth=2, n_estimators= 20,random_state=21)

# %%
model = rfc.fit(xtrain,ytrain)
pred_tr = model.predict(xtrain)
pred_ts = model.predict(xtest)
from sklearn.metrics import accuracy_score
tr_acc = accuracy_score(ytrain,pred_tr)
ts_acc = accuracy_score(ytest,pred_ts)

# %%
print("tr_acc",tr_acc)

print("ts_acc",ts_acc)
# Out:
# tr_acc 0.834051724137931
# ts_acc 0.7413793103448276

# %% [markdown]
# # Getting Data ready for predictions

# %%
B1 = Ts_set[X.columns].head()

# %%
B1.isna().sum()
# Out:
# Credit_History       0
# CoapplicantIncome    0
# Property_Area        0
# Education            0
# Married              0
# dtype: int64

# %%
cat = []
con = []
for i in Ts_set.columns:
    if(Ts_set[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
B1 = pd.DataFrame(ss.transform(Ts_set[con]),columns=con)
B2 = pd.get_dummies(Ts_set[cat])
Bnew = B1.join(B2)

# %%
ready_for_pred=Bnew[Xnew.columns]

# %%
predicted_final = model.predict(ready_for_pred)

# %%
F = pd.DataFrame([Ts_set.Loan_ID,predicted_final])
E = F.T
E.columns = ["Loan_ID","Loan_Status"]

# %%
E.to_csv("E:/DS_HMWRKS/PROJECT2/MySolutions/MySolutions.csv")

# %%
E
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
F
# Out:
#                 0         1         2         3         4         5    \
# Loan_ID    LP001015  LP001022  LP001031  LP001035  LP001051  LP001054
# Unnamed 0         Y         Y         Y         Y         Y         Y
#
#                 6         7         8         9    ...       357       358  \
# Loan_ID    LP001055  LP001056  LP001059  LP001067  ...  LP002952  LP002954
# Unnamed 0         Y         N         Y         Y  ...         Y         Y
#
#                 359       360       361       362       363       364  \
# Loan_ID    LP002962  LP002965  LP002969  LP002971  LP002975  LP002980
# Unnamed 0         Y         Y         Y         Y         Y         Y
#
#                 365       366
# Loan_ID    LP002986  LP002989
# Unnamed 0         Y         Y
#
# [2 rows x 367 columns]
