# %%
import pandas as pd
from warnings import filterwarnings
filterwarnings("ignore")

# %%
A=pd.read_csv("E:/DS_HMWRKS/PROJECT3/HR-Employee-Attrition-Table 1.csv")

# %%
A.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
A.skew()
# Out:
# Attrition                   1.844366
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# ...

# %%
#high skew cols = Attrition,DistanceFromHome,JobLevel,MonthlyIncome,NumCompaniesWorked,PerformanceRating,StockOptionLevel,TotalWorkingYears,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager

# %% [raw]
# from numpy import log
# q=[]
# for i in A.Attrition:
#     if(i!=0):
#         q.append(log(i))
#     else:
#         q.append(i)
# A.Attrition=q
# A.Attrition.skew()

# %%
from numpy import log
q=[]
for i in A.DistanceFromHome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.DistanceFromHome=q  
A.DistanceFromHome.skew()
# Out:
# -0.2460041611908789

# %%
from numpy import log
q=[]
for i in A.JobLevel:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.JobLevel=q  
A.JobLevel.skew()
# Out:
# 0.2197629343674635

# %%
from numpy import log
q=[]
for i in A.MonthlyIncome:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.MonthlyIncome=q  
A.MonthlyIncome.skew()
# Out:
# 0.2861922926389174

# %%
from numpy import log
q=[]
for i in A.NumCompaniesWorked:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.NumCompaniesWorked=q  
A.NumCompaniesWorked.skew()
# Out:
# 0.48796164700602257

# %%
from numpy import log
q=[]
for i in A.PerformanceRating:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.PerformanceRating=q  
A.PerformanceRating.skew()
# Out:
# 1.9218827021426126

# %%
from numpy import log
q=[]
for i in A.StockOptionLevel:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.StockOptionLevel=q  
A.StockOptionLevel.skew()
# Out:
# 2.0609597220168605

# %%
from numpy import log
q=[]
for i in A.TotalWorkingYears:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.TotalWorkingYears=q  
A.TotalWorkingYears.skew()
# Out:
# -0.8842373989669954

# %%
from numpy import log
q=[]
for i in A.YearsAtCompany:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.YearsAtCompany=q  
A.YearsAtCompany.skew()
# Out:
# -0.278255142630413

# %%
from numpy import log
q=[]
for i in A.YearsInCurrentRole:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.YearsInCurrentRole=q  
A.YearsInCurrentRole.skew()
# Out:
# 0.03216363877117735

# %%
from numpy import log
q=[]
for i in A.YearsSinceLastPromotion:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.YearsSinceLastPromotion=q  
A.YearsSinceLastPromotion.skew()
# Out:
# 1.223098276903541

# %%
from numpy import log
q=[]
for i in A.YearsWithCurrManager:
    if(i!=0):
        q.append(log(i))
    else:
        q.append(i)
A.YearsWithCurrManager=q  
A.YearsWithCurrManager.skew()
# Out:
# 0.03830180363880683

# %%
A.Attrition.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#CLASSIFICATION
Q=[]
for i in A.Attrition:
    if(i<1):
        Q.append("Yes")
    else:
        Q.append("No")

        
A.Attrition = Q

    
Z=A[["Attrition"]]

# %%
Q
# Out:
# ['No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
# ...

# %%
print(A.Attrition)
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 1465    Yes
# 1466    Yes
# 1467    Yes
# 1468    Yes
# 1469    Yes
# Name: Attrition, Length: 1470, dtype: object

# %%
for i in A.columns:
    print(i,A[i].unique())
# Out:
# Attrition ['No' 'Yes']
# Age [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# BusinessTravel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# DailyRate [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
# ...

# %%
#non imp cols=(EmployeeCount,Over18,StandardHours)
#con_cols_convert_to_cata_cols=({JobSatisfaction [4 2 3 1]},{JobInvolvement [3 2 4 1]},{Education [2 1 4 3 5]},{RelationshipSatisfaction [1 4 2 3]},{WorkLifeBalance [1 3 2 4]})

# %%
#{WorkLifeBalance [1 3 2 4]}
RR=pd.DataFrame(A.WorkLifeBalance)
R=[]
for i in A.WorkLifeBalance:
    if(i==1):
        R.append("Un_Balanced")
    elif(i==2):
        R.append("Somewhat_Balanced")
    elif(i==3):
        R.append("Balanced")
    else:
        R.append("Highly_Balanced")

        
A.WorkLifeBalance = R
RR["CAT_Changed_valueS"]=A.WorkLifeBalance
RR
# Out:
#       WorkLifeBalance CAT_Changed_valueS
# 0                   1        Un_Balanced
# 1                   3           Balanced
# 2                   3           Balanced
# 3                   3           Balanced
# 4                   3           Balanced
# ...               ...                ...
# 1465                3           Balanced
# 1466                3           Balanced
# 1467                3           Balanced
# 1468                2  Somewhat_Balanced
# 1469                4    Highly_Balanced
#
# [1470 rows x 2 columns]

# %%
#{RelationshipSatisfaction [1 4 2 3]}
RR=pd.DataFrame(A.RelationshipSatisfaction)
R=[]
for i in A.RelationshipSatisfaction:
    if(i==1):
        R.append("Un_Satisfied")
    elif(i==2):
        R.append("Somewhat_Satisfied")
    elif(i==3):
        R.append("Satisfied")
    else:
        R.append("Highly_Satisfied")

        
A.RelationshipSatisfaction = R
RR["CAT_Changed_valueS"]=A.RelationshipSatisfaction
RR
# Out:
#       RelationshipSatisfaction  CAT_Changed_valueS
# 0                            1        Un_Satisfied
# 1                            4    Highly_Satisfied
# 2                            2  Somewhat_Satisfied
# 3                            3           Satisfied
# 4                            4    Highly_Satisfied
# ...                        ...                 ...
# 1465                         3           Satisfied
# 1466                         1        Un_Satisfied
# 1467                         2  Somewhat_Satisfied
# 1468                         4    Highly_Satisfied
# 1469                         1        Un_Satisfied
#
# [1470 rows x 2 columns]

# %%
#{Education [2 1 4 3 5]}
RR=pd.DataFrame(A.Education)
R=[]
for i in A.Education:
    if(i==1):
        R.append("UN_EDU")
    elif(i==2):
        R.append("Somewhat_UN_Edu")
    elif(i==3):
        R.append("Edu")
    elif(i==4):
        R.append("Somewhat_Highly_Edu")
    else:
        R.append("Highly_EDU")

        
A.Education = R
RR["CAT_Changed_valueS"]=A.Education
RR
# Out:
#       Education   CAT_Changed_valueS
# 0             2      Somewhat_UN_Edu
# 1             1               UN_EDU
# 2             2      Somewhat_UN_Edu
# 3             4  Somewhat_Highly_Edu
# 4             1               UN_EDU
# ...         ...                  ...
# 1465          2      Somewhat_UN_Edu
# 1466          1               UN_EDU
# 1467          3                  Edu
# 1468          3                  Edu
# 1469          3                  Edu
#
# [1470 rows x 2 columns]

# %%
#{JobInvolvement [3 2 4 1]}
RR=pd.DataFrame(A.JobInvolvement )
R=[]
for i in A.JobInvolvement :
    if(i==1):
        R.append("Non_inv")
    elif(i==2):
        R.append("Somewhat_inv")
    elif(i==3):
        R.append("inv")
    else:
        R.append("Highly_inv")

        
A.JobInvolvement  = R
RR["CAT_Changed_valueS"]=A.JobInvolvement 
RR
# Out:
#       JobInvolvement CAT_Changed_valueS
# 0                  3                inv
# 1                  2       Somewhat_inv
# 2                  2       Somewhat_inv
# 3                  3                inv
# 4                  3                inv
# ...              ...                ...
# 1465               4         Highly_inv
# 1466               2       Somewhat_inv
# 1467               4         Highly_inv
# 1468               2       Somewhat_inv
# 1469               4         Highly_inv
#
# [1470 rows x 2 columns]

# %%
#{JobSatisfaction [4 2 3 1]}
RR=pd.DataFrame(A.JobSatisfaction )
R=[]
for i in A.JobSatisfaction :
    if(i==1):
        R.append("un_sat")
    elif(i==2):
        R.append("Somewhat_sat")
    elif(i==3):
        R.append("sat")
    else:
        R.append("Highly_sat")

        
A.JobSatisfaction  = R
RR["CAT_Changed_valueS"]=A.JobSatisfaction 
RR
# Out:
#       JobSatisfaction CAT_Changed_valueS
# 0                   4         Highly_sat
# 1                   2       Somewhat_sat
# 2                   3                sat
# 3                   3                sat
# 4                   2       Somewhat_sat
# ...               ...                ...
# 1465                4         Highly_sat
# 1466                1             un_sat
# 1467                2       Somewhat_sat
# 1468                2       Somewhat_sat
# 1469                3                sat
#
# [1470 rows x 2 columns]

# %%
A=A.drop(labels=["EmployeeCount","Over18","StandardHours"],axis=1)

# %%
A.isna().sum()
# Out:
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
cat = []
con = []
for i in A.columns:
        if(A[i].dtypes == "object"):
            cat.append(i)
        else:
            con.append(i)

# %%
print(cat)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'Gender', 'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction', 'WorkLifeBalance']

# %%
print(con)
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobLevel', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
#MSD
for i in con:
        x = A[i].mean()
        A[i]=A[i].fillna(x)

for i in cat:
        x = A[i].mode()[0]
        A[i]=A[i].fillna(x)

# %%
X=pd.DataFrame(A[A.columns])

# %%
X
# Out:
#      Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0           No   41      Travel_Rarely       1102                   Sales
# 1          Yes   49  Travel_Frequently        279  Research & Development
# 2           No   37      Travel_Rarely       1373  Research & Development
# 3          Yes   33  Travel_Frequently       1392  Research & Development
# 4          Yes   27      Travel_Rarely        591  Research & Development
# ...        ...  ...                ...        ...                     ...
# 1465       Yes   36  Travel_Frequently        884  Research & Development
# 1466       Yes   39      Travel_Rarely        613  Research & Development
# 1467       Yes   27      Travel_Rarely        155  Research & Development
# 1468       Yes   49  Travel_Frequently       1023                   Sales
# 1469       Yes   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome            Education EducationField  EmployeeNumber  \
# ...

# %%
CON=pd.DataFrame(con)
CAT=pd.DataFrame(cat)
print(CON)
print(CAT)
# Out:
#                           0
# 0                       Age
# 1                 DailyRate
# 2          DistanceFromHome
# 3            EmployeeNumber
# 4   EnvironmentSatisfaction
# 5                HourlyRate
# 6                  JobLevel
# 7             MonthlyIncome
# 8               MonthlyRate
# 9        NumCompaniesWorked
# 10        PercentSalaryHike
# 11        PerformanceRating
# 12         StockOptionLevel
# 13        TotalWorkingYears
# 14    TrainingTimesLastYear
# 15           YearsAtCompany
# 16       YearsInCurrentRole
# 17  YearsSinceLastPromotion
# 18     YearsWithCurrManager
#                            0
# 0                  Attrition
# 1             BusinessTravel
# 2                 Department
# 3                  Education
# 4             EducationField
# 5                     Gender
# 6             JobInvolvement
# 7                    JobRole
# 8            JobSatisfaction
# 9              MaritalStatus
# 10                  OverTime
# ...

# %%
from statsmodels.formula.api import ols
model = ols("Age ~ Attrition",A).fit()
from statsmodels.stats.anova import anova_lm
anova_results = anova_lm(model)
pval = list(anova_results[["PR(>F)"]].values)[0][0]
print("Pvalue: ",round(pval,4))
if(pval < 0.05):
    print("Dependent")
else:
    print("Independent")
# Out:
# Pvalue:  0.0
# Dependent

# %%
CON_TR=CON.T
CON_TR.columns=con
print(CON_TR)

CAT_TR=CAT.T
CAT_TR.columns=cat
print(CAT_TR)
# Out:
#    Age  DailyRate  DistanceFromHome  EmployeeNumber  EnvironmentSatisfaction  \
# 0  Age  DailyRate  DistanceFromHome  EmployeeNumber  EnvironmentSatisfaction
#
#    HourlyRate  JobLevel  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0  HourlyRate  JobLevel  MonthlyIncome  MonthlyRate  NumCompaniesWorked
#
#    PercentSalaryHike  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# 0  PercentSalaryHike  PerformanceRating  StockOptionLevel  TotalWorkingYears
#
#    TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0  TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0  YearsSinceLastPromotion  YearsWithCurrManager
#    Attrition  BusinessTravel  Department  Education  EducationField  Gender  \
# 0  Attrition  BusinessTravel  Department  Education  EducationField  Gender
#
#    JobInvolvement  JobRole  JobSatisfaction  MaritalStatus  OverTime  \
# ...

# %%
for i in CON_TR:
    print(i)
print("*******************************************************")
print("=======================================================")
for i in CAT_TR:
    print(i)
# Out:
# Age
# DailyRate
# DistanceFromHome
# EmployeeNumber
# EnvironmentSatisfaction
# HourlyRate
# JobLevel
# MonthlyIncome
# MonthlyRate
# NumCompaniesWorked
# PercentSalaryHike
# PerformanceRating
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager
# *******************************************************
# ...
# Attrition
# BusinessTravel
# Department
# Education
# EducationField
# Gender
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# OverTime
# RelationshipSatisfaction
# WorkLifeBalance

# %% [raw]
# from PM007 import ANOVA,chisquare
# for i in CON_TR:
#     pval=(ANOVA(A,Z,i))
#
# print("Pvalue: ",round(pval,4))
# if(pval < 0.05):
#     print("Dependent")
# else:
#     print("Independent")

# %%
imp_cols_ANOVA=[]
un_imp_cols_ANOVA=[]
for i in CON_TR:
    from statsmodels.formula.api import ols
    model = ols("A[i] ~ Attrition",A).fit()
    from statsmodels.stats.anova import anova_lm
    anova_results = anova_lm(model)
    pval = list(anova_results[["PR(>F)"]].values)[0][0]
    print("Pvalue: ",round(pval,4))
    if(pval < 0.05):
        print(i,"Dependent")
        print("********************")
        imp_cols_ANOVA.append(i)
    else:
        print(i,"Independent")
        print("====================")
        un_imp_cols_ANOVA.append(i)
# Out:
# Pvalue:  0.0
# Age Dependent
# ********************
# Pvalue:  0.0299
# DailyRate Dependent
# ********************
# Pvalue:  0.0034
# DistanceFromHome Dependent
# ********************
# Pvalue:  0.6853
# EmployeeNumber Independent
# ...
# Pvalue:  0.0001
# EnvironmentSatisfaction Dependent
# ********************
# Pvalue:  0.7931
# HourlyRate Independent
# ...
# Pvalue:  0.0
# JobLevel Dependent
# ********************
# Pvalue:  0.0
# MonthlyIncome Dependent
# ********************
# Pvalue:  0.5611
# MonthlyRate Independent
# ...
# Pvalue:  0.4473
# NumCompaniesWorked Independent
# ...
# Pvalue:  0.6056
# PercentSalaryHike Independent
# ...
# Pvalue:  0.9119
# PerformanceRating Independent
# ...
# Pvalue:  0.0794
# StockOptionLevel Independent
# ...
# Pvalue:  0.0
# TotalWorkingYears Dependent
# ********************
# Pvalue:  0.0226
# TrainingTimesLastYear Dependent
# ********************
# Pvalue:  0.0
# YearsAtCompany Dependent
# ********************
# Pvalue:  0.0
# YearsInCurrentRole Dependent
# ********************
# ...

# %%
imp_cols_ANOVA
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'EnvironmentSatisfaction',
#  'JobLevel',
#  'MonthlyIncome',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsWithCurrManager']

# %%
un_imp_cols_ANOVA
# Out:
# ['EmployeeNumber',
#  'HourlyRate',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'StockOptionLevel',
#  'YearsSinceLastPromotion']

# %% [raw]
# imp_cols_chi2_contingency=[]
# for i in CAT_TR:
#     from scipy.stats import chi2_contingency
#     import pandas as pd
#     ct = pd.crosstab(A[i],Z)
#     a,b,c,d = chi2_contingency(ct)
#     print(a,type(a))
#     print(b,type(b))
#     print(c,type(c))
#     print(d,type(d))
#     print("___________**********____________")
#     print("-----------++++++++++------------")

# %%
X = X.drop(labels=['Attrition','EmployeeNumber','HourlyRate','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','StockOptionLevel','YearsSinceLastPromotion'],axis=1)

# %%
X
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome            Education EducationField  \
# 0             0.000000      Somewhat_UN_Edu  Life Sciences
# 1             2.079442               UN_EDU  Life Sciences
# ...

# %% [raw]
# import matplotlib.pyplot as plt
# import seaborn as sb
# plt.figure(figsize=(20,40))
# var=1
# for i in X.columns:
#     if(X[i].dtypes == "object"):
#         plt.subplot(6,3,var)
#         sb.histplot(binwidth=0.5, x="Attrition", hue="i", data=X, stat="count", multiple="stack")
#         var=var+1
#     else:
#         plt.subplot(6,2,var)
#         X[i].hist()
#         var=var+1

# %%
cat_new = []
con_new = []
for i in X.columns:
    if(X[i].dtypes == "object"):
        cat_new.append(i)
    else:
        con_new.append(i)

# %%
print(cat_new)
print("***********************")
print("=======================")
print(con_new)
# Out:
# ['BusinessTravel', 'Department', 'Education', 'EducationField', 'Gender', 'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction', 'WorkLifeBalance']
# ***********************
# ...
# ['Age', 'DailyRate', 'DistanceFromHome', 'EnvironmentSatisfaction', 'JobLevel', 'MonthlyIncome', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X1 = pd.DataFrame(ss.fit_transform(X[con_new]),columns=con_new)

# %%
X2 = pd.get_dummies(X[cat_new])
Xnew = X1.join(X2)

# %%
Xnew
# Out:
#            Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# 0     0.446350   0.742527         -1.644714                -0.660531
# 1     1.322365  -1.297775          0.317324                 0.254625
# 2     0.008343   1.414363         -0.990702                 1.169781
# 3    -0.429664   1.461466         -0.608129                 1.169781
# 4    -1.086676  -0.524295         -0.990702                -1.575686
# ...        ...        ...               ...                      ...
# 1465 -0.101159   0.202082          1.313752                 0.254625
# 1466  0.227347  -0.469754          0.045884                 1.169781
# 1467 -1.086676  -1.605183         -0.336689                -0.660531
# 1468  1.322365   0.546677         -0.990702                 1.169781
# 1469 -0.320163  -0.432568          0.317324                -0.660531
#
#       JobLevel  MonthlyIncome  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(Xnew,Z,test_size=0.2,random_state=31)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
model = lr.fit(xtrain,ytrain)

# %%
pred_tr = model.predict(xtrain)
pred_ts = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_ts)
# Out:
# 0.8843537414965986

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(ytest,pred_ts)
# Out:
# array([[ 21,  21],
#        [ 13, 239]], dtype=int64)

# %%
ytest.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
QQ = pd.DataFrame(ytest)
QQ['predicted_Attrition']=pred_ts

# %%
QQ
# Out:
#      Attrition predicted_Attrition
# 1343       Yes                 Yes
# 334        Yes                 Yes
# 1136        No                  No
# 1080       Yes                 Yes
# 396        Yes                 Yes
# ...        ...                 ...
# 91         Yes                  No
# 520        Yes                 Yes
# 1403       Yes                 Yes
# 479         No                  No
# 1135       Yes                 Yes
#
# [294 rows x 2 columns]

# %%
len(QQ.Attrition)
# Out:
# 294
